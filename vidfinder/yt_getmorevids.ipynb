# %%
from googleapiclient.discovery import build

api_key = 'AIzaSyDIb1z0egWzRZalvd4kYIU1MmDnmyguUMk'

youtube = build('youtube', 'v3', developerKey=api_key)

# %%
# res = youtube.channels().list(id='UCtTGHXzzchvZXmA_PyEcnCA', part='snippet',maxResults=50).execute()

# %%
def get_channel_videos(channel_id):
    
    # get Uploads playlist id
    res = youtube.channels().list(id=channel_id, 
                                  part='contentDetails').execute()
    playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    
    videos = []
    next_page_token = None
    
    while 1:
        res = youtube.playlistItems().list(playlistId=playlist_id, 
                                           part='snippet', 
                                           maxResults=50,
                                           pageToken=next_page_token).execute()
        for item in res['items']:
            if item['snippet']['channelId'] == channel_id:
                videos.append(item)
            
#         videos += res['items']
        next_page_token = res.get('nextPageToken')
        
        if next_page_token is None:
            break
    
    return videos

# %%
videos = get_channel_videos('UCkUq-s6z57uJFUFBvZIVTyg')

# %%
len(videos)
# Out:
# 270

# %%
print(videos[0])
# Out:
# {'kind': 'youtube#playlistItem', 'etag': 'e2vzD58xBk6P6HSDo_ZTvfwoV34', 'id': 'VVVrVXEtczZ6NTd1SkZVRkJ2WklWVHlnLk00Nkg0R0lkZmww', 'snippet': {'publishedAt': '2020-08-30T17:14:07Z', 'channelId': 'UCkUq-s6z57uJFUFBvZIVTyg', 'title': 'Unit Testing in Python with pytest | Advanced Mocking (Part-10)', 'description': 'In this video, we cover some advanced mocking scenarios.\n\n\nCode: https://github.com/nikhilkumarsingh/pytest-tut\nPlaylist: https://www.youtube.com/playlist?list=PLyb_C2HpOQSBWGekd7PfhHnb9GnqDgrxS\n\n\n\n------------------------------------------------------------\n\nExplore my tutorials: https://nikhilkumarsingh.github.io/tutorials/\n\nMore awesome topics covered here:\nWhatsApp Bot using Twilio and Python : https://tinyurl.com/y9n9ott5\nServerless Rest API using AWS and Python : https://tinyurl.com/y8yg4vem\nCreating Chat Application using Flask, Socket.IO & mongoDB : https://tinyurl.com/y8kbn4xu\nCurses in Python : https://tinyurl.com/y8ws3x4l\nDiscovering Hidden APIs : 
# ...

# %%
for video in videos:
    print(video['snippet']['title'],'----',video['snippet']['resourceId']['videoId'])
# Out:
# Unit Testing in Python with pytest | Advanced Mocking (Part-10) ---- M46H4GIdfl0
# Unit Testing in Python with pytest | Introduction to mock (Part-9) ---- dw2eNCzwBkk
# Unit Testing in Python with pytest | Parametrizing Unit Tests (Part-4) ---- XHEvvY1qjPY
# Unit Testing in Python with pytest | Parametrizing Fixtures (Part-8) ---- YmSYW-Ha78M
# Unit Testing in Python with pytest | Creating Fixture Factory (Part-7) ---- TXj1aYldUsI
# Unit Testing in Python with pytest | Creating Custom Fixture (Part-6) ---- pFKHYekCqbU
# Unit Testing in Python with pytest | Introduction to Fixtures (Part-5) ---- jmh1nKz7SjQ
# Unit Testing in Python with pytest | Introduction to Markers (Part-3) ---- ArrNCcIXSIk
# Unit Testing in Python with pytest | Asserting Expected Exceptions (Part-2) ---- R7u8xWXCbGM
# Unit Testing in Python with pytest | Getting Started (Part-1) ---- L6N3BgZh2AA
# Plotting Choropleth Maps using Python (Plotly) ---- aJmaw3QKMvk
# ...

# %%
videos2 = get_channel_videos('UCtTGHXzzchvZXmA_PyEcnCA')

# %%
for video in videos2:
    print(video['snippet']['title'],'----',video['snippet']['publishedAt'],'----',video['snippet']['resourceId']['videoId'])
# Out:
# Hamas Lies   Dead Bodies that Move ---- 2015-08-27T17:01:48Z ---- bJFdkX0MGQQ
# Libera in America Live concert song   Wayfaring Stranger 2015 ---- 2015-08-21T16:14:21Z ---- softc5V8Yvw
# LIBERA CHOIR What a Wonderful World 2015 ---- 2015-08-03T02:12:24Z ---- ZJf0ynwtl9I
# THE CARTOONISTS AND ISLAM ---- 2015-07-04T05:57:46Z ---- pXj52Ksxfak
# America's Got Talent 2015 10th edition Eline 7 & Noah 8 in DANCING ACT ---- 2015-05-31T04:27:29Z ---- bFRMQU5UNGo
# libera chorister photos 2013 song  Orinoco Flow ---- 2015-05-24T08:43:39Z ---- UjSxfV5nyNI
# Libera  'Prayer' march 2015 Libera Choir UK ---- 2015-05-23T19:26:21Z ---- xrDOfaxzmM0
# Libera   Behind the Scenes ---- 2015-04-27T23:27:16Z ---- bKDrn4RfJqU
# Is Islam religion of peace in cartoons & pictures ---- 2015-04-14T02:39:08Z ---- h7HYDUnLZs8
# THE TRUE FACE OF ISLAM  IN CARTOONS & PICTURES PART THREE ---- 2015-04-08T22:49:15Z ---- CfwPQqleak0
# ...

# %%
len(videos2)
# Out:
# 594

# %%
videos2[0]
# Out:
# {'kind': 'youtube#playlistItem',
#  'etag': 'Jq58afhJn9l8A30Saw_BbxtQa5g',
#  'id': 'VVV0VEdIWHp6Y2h2WlhtQV9QeUVjbkNBLmJKRmRrWDBNR1FR',
#  'snippet': {'publishedAt': '2015-08-27T17:01:48Z',
#   'channelId': 'UCtTGHXzzchvZXmA_PyEcnCA',
#   'title': 'Hamas Lies   Dead Bodies that Move',
#   'description': 'Before Trying to Fake Civilian Casualties, You May Want to Make Sure The cameras Aren’t Rolling',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/bJFdkX0MGQQ/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/bJFdkX0MGQQ/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/bJFdkX0MGQQ/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Islam Twofaces',
#   'playlistId': 'UUtTGHXzzchvZXmA_PyEcnCA',
#   'position': 0,
#   'resourceId': {'kind': 'youtube#video', 'videoId': 'bJFdkX0MGQQ'},
#   'videoOwnerChannelTitle': 'Islam Twofaces',
# ...

# %%
import csv

# %%
import pandas as pd

# %%
chans = pd.read_csv('ytchan.csv')

# %%
chans.columns = ['id', 'val', 'type', 'consp']

# %%
ids = chans.id

# %%
len(ids)
# Out:
# 37128

# %%
ids2 = ids.drop_duplicates()

# %%
len(ids2)
# Out:
# 1902

# %%
ids2 = []
seen = {}
infile = open('conspiracy_channels.txt', 'r')
for line in infile:
    line = line.strip()
    if line in seen:
        seen[line] += 1
    else:
        seen[line] = 1
    ids2.append(line)
infile.close()

# %%
# Out:
# ['UCuftdXePz6z73Wsg8Ao5lTg', 'UC4F3j3ed_To-M3H2YLLD5vw', 'UCHE92x768p8h-fMrqhsnE1Q', 'UCjCPA4n3dkHOnAFN7koLOlA', 'UC7TvL4GlQyMBLlUsTrN_C4Q', 'UCwJq9pqEEUr5_OmwBWQxDKA', 'UC2nQYGjfe9I_tgWpqgJorUg', 'UCA071Pllf2wk-B8Rkwt47bQ', 'UCv_-yc055n1fxFfTYpdaKBg', 'UCNqkB9BhN0cVXlanwIsNL8w', 'UCOnnmKlDZltHAqJLz-XIpGA', 'UC0v7VUtxrPnQWPgZx-WSzgw', 'UCsIlJ9eYylZQcyfMOPNUz9w', 'UCVEaFSr-jdTa_QE4PPSkVJw', 'UCVmlEoDSeImXV5aPz8EvP0A', 'UCkKOQNYoZjaa_8V0uPOueeQ', 'UCG-G8LLr38fQUNZU8K0t-EA', 'UCqObSfoC2hZh0SmQFMHLdJw', 'UCKpH2KFEngc9Csp2i71znYA', 'UCJkOZZrGNEJYDhzVwd24Bfg', 'UCZAfwtPpZyByqTcTmvJuy0g', 'UC7KZFVVnKjiCzkxWD-Qrakg', 'UCDATi9UrhqjfVNxIKNizOiQ', 'UC23R7E4-4-uICO-_Dq5IqUg', 'UCY-UU3bN4FkMILC-CMd8N5w', 'UC98Zwfvjq12M1oi99Yqd78w', 'UC8UexTu0pRdzJU83eLXGPIA', 'UCuIfBWQn2lj_IOKW2Woaoug', 'UCoadVWF3acwZhffVQkVKv2Q', 'UCyOMyeo5bznuFU1g-eLtEqg', 'UCvcMkIT_afFIV1VKDmIwupw', 'UCcDC6kQcOgMw1fNTwgiBn_Q', 'UCyD8iZpuGD6SieCtmKnsmEQ', 'UCMqG0kLgrRv9tODTDG12oZA', 'UChD-zWutIego-bcHKOatFWA', 'UCaasFoY9yYQpOfL
# ...

# %%
result = []
for i in ids2:
    try:
        temp = get_channel_videos(i)
    except Exception as e:
        print(e)
        pass
    for video in temp:
        out = [i,video['snippet']['title'],video['snippet']['resourceId']['videoId'],video['snippet']['publishedAt']]
        result.append(out)
# Out:
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/channels?id=UCuftdXePz6z73Wsg8Ao5lTg&part=contentDetails&key=AIzaSyDIb1z0egWzRZalvd4kYIU1MmDnmyguUMk&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-4f0d97bd7cf6> in <module>
#       6         print(e)
#       7         pass
# ----> 8     for video in temp:
#       9         out = [i,video['snippet']['title'],video['snippet']['resourceId']['videoId'],video['snippet']['publishedAt']]
#      10         result.append(out)
#
# ...

# %%
df = pd.DataFrame(result, columns=['chanId','vidTitle','vidId','date'])

# %%
len(result)
# Out:
# 221351

# %%
# for i in mylist:
#   if i not in newlist:
#     newlist.append(i)
# Out:
# 'UCB1o7_gbFp2PLsamWxFenBg'

# %%
# pd.melt(chans, id_vars=['id','val'])

# %%
chansA = chans.groupby(by=['id','val'])['type'].apply(list)
chansB = chans.groupby(by=['id','val'])['consp'].apply(list)

# %%
chan_info = pd.concat([chansA,chansB], axis=1, join='inner')

# %%
chan_info = pd.DataFrame(chan_info)

# %%
chan_info = chan_info.reset_index()

# %%
test = df.merge(chan_info,left_on='chanId', right_on='id')

# %%
del test['id']

# %%
final = test

# %%
final
# Out:
#                            chanId  \
# 0        UC0aanx5rpr7D1M7KCFYzrLQ
# 1        UC0aanx5rpr7D1M7KCFYzrLQ
# 2        UC0aanx5rpr7D1M7KCFYzrLQ
# 3        UC0aanx5rpr7D1M7KCFYzrLQ
# 4        UC0aanx5rpr7D1M7KCFYzrLQ
# ...                           ...
# 1845474  UCtTGHXzzchvZXmA_PyEcnCA
# 1845475  UCtTGHXzzchvZXmA_PyEcnCA
# 1845476  UCtTGHXzzchvZXmA_PyEcnCA
# 1845477  UCtTGHXzzchvZXmA_PyEcnCA
# 1845478  UCtTGHXzzchvZXmA_PyEcnCA
#
#                                                   vidTitle        vidId  \
# 0                 Your 2021 Fever Dream | ℌ𝔢𝔩𝔩 𝔚𝔬𝔯𝔩𝔡 Ep. 3  KAt3eqL4RpA
# 1                               "Nice" Guys & "Nice" Girls  5JNZUaMmo-U
# 2           I Went To A Trump Rally With 1 Simple Question  yN7E4xN2IVo
# 3                                    What Happened To Men?  gyby_N9W0Zg
# 4                    The American Abyss | ℌ𝔢𝔩𝔩 𝔚𝔬𝔯𝔩𝔡 Ep. 2  XyZ7x1oduWU
# ...                                                    ...          ...
# ...

# %%
final.to_csv('Users/golds/more_vids.csv')

# %%
# final.groupby(by=['chanId']).count().tail(50)

# %%
temp2 = final[final.date > '2021-01-01']

# %%
temp2a = temp2[temp2.val >= .9]

# %%
temp2a.to_csv('Users/golds/Documents/csv1.csv')

# %%
onlyIds = temp2a.vidId

# %%
onlyIds.to_csv('Users/golds/Documents/csv2.csv')
